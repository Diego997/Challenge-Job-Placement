# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#Dataset import
data= pd.read_csv('JobPlacement.csv')

# %%
train, test = train_test_split(data, test_size=0.2)

train.to_csv('train.csv',index=False)
test.to_csv('test.csv',index=False)
